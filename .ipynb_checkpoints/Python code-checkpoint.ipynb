# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# IMPORTING THE DATASET
d = pd.read_csv('m500_lap_time_rank_ver5.csv')
df = pd.DataFrame(data=d)
df
# Out:
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 5120  2016/2017               World Cup  Gangneung     KOR  2016     12   16
# 5121  2016/2017               World Cup   Shanghai     CHN  2016     12    9
# 5122  2016/2017               World Cup  Gangneung     KOR  2016     12   16
# 5123  2016/2017               World Cup  Gangneung     KOR  2016     12   16
# 5124  2016/2017               World Cup  Gangneung     KOR  2016     12   16
#
#      Distance             Round  Group  ...  time_lap1 rank_lap2 time_lap2  \
# 0        500m     Preliminaries      1  ...       7.52       1.0      9.22
# 1        500m     Preliminaries      1  ...       7.44       2.0      9.31
# 2        500m     Preliminaries      1  ...       7.64       3.0      9.74
# 3        500m     Preliminaries      1  ...       7.46       4.0      9.93
# 4        500m     Preliminaries      2  ...       7.08       2.0      9.18
# ...       ...               ...    ...  ...        ...       ...       ...
# 5120     500m             Heats      5  ...        NaN       NaN       NaN
# 5121  500m(1)             Heats      6  ...       7.65       5.0     10.09
# 5122     500m          RepHeats      3  ...       7.02       1.0      9.16
# 5123     500m             Heats      7  ...       6.97       1.0      9.11
# 5124     500m  RepQuarterfinals      2  ...       7.13       3.0      8.89
#
#       rank_lap3  time_lap3  rank_lap4 time_lap4  rank_lap5  time_lap5  \
# 0           1.0       8.76        1.0      8.87        1.0       9.09
# 1           2.0       8.89        2.0      8.88        2.0       9.27
# 2           3.0       9.04        3.0      9.05        3.0       9.21
# 3           4.0       9.50        4.0      9.67        4.0       9.91
# 4           2.0       8.76        2.0      8.86        1.0       8.90
# ...         ...        ...        ...       ...        ...        ...
# 5120        NaN        NaN        NaN       NaN        NaN        NaN
# 5121        5.0       9.96        5.0     10.41        5.0      11.13
# 5122        2.0       8.87        2.0      8.86        3.0       9.02
# 5123        1.0       8.62        3.0      9.04        4.0       8.96
# 5124        3.0       8.34        3.0      8.44        4.0       8.81
#
#        Time_Event
# 0     2013.046575
# 1     2013.046575
# 2     2013.046575
# 3     2013.046575
# 4     2013.046575
# ...           ...
# 5120  2016.957763
# 5121  2016.938584
# 5122  2016.957763
# 5123  2016.957763
# 5124  2016.957763
#
# [5125 rows x 28 columns]

# %%
# FOR ROWS 4269 TO THE END, IT SEEMS LIKE THERE IS ADDITIONAL DATA FOR SPECIFIC ATHLETES. BECAUSE IT UNCLEAR AS TO WHICH RACES
# THESE DATA POINTS BELONG TO AND WHETHER THE FULL INFORMATION FOR THESE RACES HAVE BEEN INCLUDED, THIS PART OF THE DATA 
# WILL BE OMMITTED FROM THE PAPER

# We need to drop the last (5125 - 4269) rows
N = 5125 - 4267
df = df.iloc[:-N , :]
df
# Out:
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 4262  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4263  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4264  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4265  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4266  2015/2016               World Cup  Dordrecht     NED  2016      2   12
#
#      Distance          Round  Group  ...  time_lap1 rank_lap2 time_lap2  \
# 0        500m  Preliminaries      1  ...       7.52       1.0      9.22
# 1        500m  Preliminaries      1  ...       7.44       2.0      9.31
# 2        500m  Preliminaries      1  ...       7.64       3.0      9.74
# 3        500m  Preliminaries      1  ...       7.46       4.0      9.93
# 4        500m  Preliminaries      2  ...       7.08       2.0      9.18
# ...       ...            ...    ...  ...        ...       ...       ...
# 4262     500m         FinalA      1  ...       7.15       5.0      8.82
# 4263     500m         FinalA      1  ...       6.94       3.0      8.83
# 4264     500m         FinalA      1  ...       7.09       4.0      8.71
# 4265     500m         FinalB      2  ...        NaN       NaN       NaN
# 4266     500m         FinalB      3  ...        NaN       NaN       NaN
#
#       rank_lap3  time_lap3  rank_lap4 time_lap4  rank_lap5  time_lap5  \
# 0           1.0       8.76        1.0      8.87        1.0       9.09
# 1           2.0       8.89        2.0      8.88        2.0       9.27
# 2           3.0       9.04        3.0      9.05        3.0       9.21
# 3           4.0       9.50        4.0      9.67        4.0       9.91
# 4           2.0       8.76        2.0      8.86        1.0       8.90
# ...         ...        ...        ...       ...        ...        ...
# 4262        3.0       8.30        4.0      8.45        4.0       8.76
# 4263        5.0      18.89        5.0     13.46        5.0      15.48
# 4264        6.0      41.81        6.0     28.73        NaN        NaN
# 4265        NaN        NaN        NaN       NaN        NaN        NaN
# 4266        NaN        NaN        NaN       NaN        NaN        NaN
#
#        Time_Event
# 0     2013.046575
# 1     2013.046575
# 2     2013.046575
# 3     2013.046575
# 4     2013.046575
# ...           ...
# 4262  2016.113470
# 4263  2016.113470
# 4264  2016.113470
# 4265  2016.113470
# 4266  2016.113470
#
# [4267 rows x 28 columns]

# %%
# CERTAIN RACES WILL BE REMOVED TO GET A MORE "REPRESENTATIVE" DATASET:

# Races where there were penalties and/or there was(were) skaters that did not start/finish 
for index, row in df.iterrows():
    if (row['Qualification'] == "PEN" or row['Qualification'] == "DNF" or row['Qualification'] == "DNS"):
        df.drop(labels=(index), axis =0, inplace=True)
df
# Out:
# /opt/anaconda3/envs/sports/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 4261  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4262  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4263  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4265  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4266  2015/2016               World Cup  Dordrecht     NED  2016      2   12
#
#      Distance          Round  Group  ...  time_lap1 rank_lap2 time_lap2  \
# 0        500m  Preliminaries      1  ...       7.52       1.0      9.22
# 1        500m  Preliminaries      1  ...       7.44       2.0      9.31
# 2        500m  Preliminaries      1  ...       7.64       3.0      9.74
# 3        500m  Preliminaries      1  ...       7.46       4.0      9.93
# 4        500m  Preliminaries      2  ...       7.08       2.0      9.18
# ...       ...            ...    ...  ...        ...       ...       ...
# 4261     500m         FinalA      1  ...       7.32       6.0      8.75
# 4262     500m         FinalA      1  ...       7.15       5.0      8.82
# 4263     500m         FinalA      1  ...       6.94       3.0      8.83
# 4265     500m         FinalB      2  ...        NaN       NaN       NaN
# 4266     500m         FinalB      3  ...        NaN       NaN       NaN
#
#       rank_lap3  time_lap3  rank_lap4 time_lap4  rank_lap5  time_lap5  \
# 0           1.0       8.76        1.0      8.87        1.0      9.090
# 1           2.0       8.89        2.0      8.88        2.0      9.270
# 2           3.0       9.04        3.0      9.05        3.0      9.210
# 3           4.0       9.50        4.0      9.67        4.0      9.910
# 4           2.0       8.76        2.0      8.86        1.0      8.900
# ...         ...        ...        ...       ...        ...        ...
# 4261        4.0       8.22        3.0      8.25        3.0      8.319
# 4262        3.0       8.30        4.0      8.45        4.0      8.760
# 4263        5.0      18.89        5.0     13.46        5.0     15.480
# 4265        NaN        NaN        NaN       NaN        NaN        NaN
# 4266        NaN        NaN        NaN       NaN        NaN        NaN
#
#        Time_Event
# 0     2013.046575
# 1     2013.046575
# 2     2013.046575
# 3     2013.046575
# 4     2013.046575
# ...           ...
# 4261  2016.113470
# 4262  2016.113470
# 4263  2016.113470
# 4265  2016.113470
# 4266  2016.113470
#
# [4083 rows x 28 columns]

# %%
df = df.reset_index()

# %%
# Races where there were < or > 4 skaters: 
# a "race label" is assigned to each skater to determine which race they participated in and races whose labels are 
# counted more or less than 4 times are removed from the dataset

arr = [None]*df['City'].count()
len(arr)
label = 0
for index, row in df.iterrows():
    if (row['Rank_In_Group'] == 1):
        label=label+1
        arr[index] = label
    else:
        arr[index] = label
        
df['Race_label'] = arr

label = 1
count = 0
arrIndex = 0;
arrCounts = [None]*1016
for index, row in df.iterrows():
    if (df.iloc[index]["Race_label"] == label):
        count=count+1
    else:
        arrCounts[arrIndex]=count
        arrIndex = arrIndex+1
        label=label+1
        count=1

# %%
df
# Out:
#       index     Season                  Series       City Country  Year  \
# 0         0  2012/2013  European Championships      Malmo     SWE  2013
# 1         1  2012/2013  European Championships      Malmo     SWE  2013
# 2         2  2012/2013  European Championships      Malmo     SWE  2013
# 3         3  2012/2013  European Championships      Malmo     SWE  2013
# 4         4  2012/2013  European Championships      Malmo     SWE  2013
# ...     ...        ...                     ...        ...     ...   ...
# 4078   4261  2015/2016               World Cup  Dordrecht     NED  2016
# 4079   4262  2015/2016               World Cup  Dordrecht     NED  2016
# 4080   4263  2015/2016               World Cup  Dordrecht     NED  2016
# 4081   4265  2015/2016               World Cup  Dordrecht     NED  2016
# 4082   4266  2015/2016               World Cup  Dordrecht     NED  2016
#
#       Month  Day Distance          Round  ...  rank_lap2  time_lap2 rank_lap3  \
# 0         1   18     500m  Preliminaries  ...        1.0       9.22       1.0
# 1         1   18     500m  Preliminaries  ...        2.0       9.31       2.0
# 2         1   18     500m  Preliminaries  ...        3.0       9.74       3.0
# 3         1   18     500m  Preliminaries  ...        4.0       9.93       4.0
# 4         1   18     500m  Preliminaries  ...        2.0       9.18       2.0
# ...     ...  ...      ...            ...  ...        ...        ...       ...
# 4078      2   12     500m         FinalA  ...        6.0       8.75       4.0
# 4079      2   12     500m         FinalA  ...        5.0       8.82       3.0
# 4080      2   12     500m         FinalA  ...        3.0       8.83       5.0
# 4081      2   12     500m         FinalB  ...        NaN        NaN       NaN
# 4082      2   12     500m         FinalB  ...        NaN        NaN       NaN
#
#      time_lap3  rank_lap4  time_lap4  rank_lap5 time_lap5   Time_Event  \
# 0         8.76        1.0       8.87        1.0     9.090  2013.046575
# 1         8.89        2.0       8.88        2.0     9.270  2013.046575
# 2         9.04        3.0       9.05        3.0     9.210  2013.046575
# 3         9.50        4.0       9.67        4.0     9.910  2013.046575
# 4         8.76        2.0       8.86        1.0     8.900  2013.046575
# ...        ...        ...        ...        ...       ...          ...
# 4078      8.22        3.0       8.25        3.0     8.319  2016.113470
# 4079      8.30        4.0       8.45        4.0     8.760  2016.113470
# 4080     18.89        5.0      13.46        5.0    15.480  2016.113470
# 4081       NaN        NaN        NaN        NaN       NaN  2016.113470
# 4082       NaN        NaN        NaN        NaN       NaN  2016.113470
#
#       Race_label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              2
# ...          ...
# 4078        1014
# 4079        1014
# 4080        1014
# 4081        1015
# 4082        1016
#
# [4083 rows x 30 columns]

# %%
# Removing the races whose label count are ≠ 4
