# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# IMPORTING THE DATASET
d = pd.read_csv('m500_lap_time_rank_ver5.csv')
df = pd.DataFrame(data=d)

# FOR ROWS 4267 TO THE END, THERE IS ADDITIONAL DATA FOR SPECIFIC ATHLETES. BECAUSE IT UNCLEAR AS TO WHICH RACES
# THESE DATA POINTS BELONG TO AND WHETHER THE FULL INFORMATION FOR THESE RACES HAVE BEEN INCLUDED, THIS PART OF 
# THE DATA WILL BE OMMITTED FROM THE PAPER
N = 5125 - 4267
df = df.iloc[:-N , :]
df
# Out:
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 4262  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4263  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4264  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4265  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 4266  2015/2016               World Cup  Dordrecht     NED  2016      2   12
#
#      Distance          Round  Group  ...  time_lap1 rank_lap2 time_lap2  \
# 0        500m  Preliminaries      1  ...       7.52       1.0      9.22
# 1        500m  Preliminaries      1  ...       7.44       2.0      9.31
# 2        500m  Preliminaries      1  ...       7.64       3.0      9.74
# 3        500m  Preliminaries      1  ...       7.46       4.0      9.93
# 4        500m  Preliminaries      2  ...       7.08       2.0      9.18
# ...       ...            ...    ...  ...        ...       ...       ...
# 4262     500m         FinalA      1  ...       7.15       5.0      8.82
# 4263     500m         FinalA      1  ...       6.94       3.0      8.83
# 4264     500m         FinalA      1  ...       7.09       4.0      8.71
# 4265     500m         FinalB      2  ...        NaN       NaN       NaN
# 4266     500m         FinalB      3  ...        NaN       NaN       NaN
#
#       rank_lap3  time_lap3  rank_lap4 time_lap4  rank_lap5  time_lap5  \
# 0           1.0       8.76        1.0      8.87        1.0       9.09
# 1           2.0       8.89        2.0      8.88        2.0       9.27
# 2           3.0       9.04        3.0      9.05        3.0       9.21
# 3           4.0       9.50        4.0      9.67        4.0       9.91
# 4           2.0       8.76        2.0      8.86        1.0       8.90
# ...         ...        ...        ...       ...        ...        ...
# 4262        3.0       8.30        4.0      8.45        4.0       8.76
# 4263        5.0      18.89        5.0     13.46        5.0      15.48
# 4264        6.0      41.81        6.0     28.73        NaN        NaN
# 4265        NaN        NaN        NaN       NaN        NaN        NaN
# 4266        NaN        NaN        NaN       NaN        NaN        NaN
#
#        Time_Event
# 0     2013.046575
# 1     2013.046575
# 2     2013.046575
# 3     2013.046575
# 4     2013.046575
# ...           ...
# 4262  2016.113470
# 4263  2016.113470
# 4264  2016.113470
# 4265  2016.113470
# 4266  2016.113470
#
# [4267 rows x 28 columns]

# %%
# CLEANING THE DATA: CERTAIN RACES WILL BE REMOVED TO GET A MORE REPRESENTATIVE DATASET:


# 1) Races where there were penalties and/or did not start/finish outcomes: 
# the data point of the athlete with this outcome is removed, the race itself will be removed at (3)
for index, row in df.iterrows():
    if (row['Qualification'] == "PEN" or row['Qualification'] == "DNF" or row['Qualification'] == "DNS"):
        df.drop(labels=(index), axis =0, inplace=True)
df = df.reset_index(drop=True)


# 2) Races with missing data
for index, row in df.iterrows():
    if (np.isnan(row['rank_lap1']) or np.isnan(row['rank_lap2']) or np.isnan(row['rank_lap3']) or np.isnan(row['rank_lap4']) or np.isnan(row['rank_lap5'])): 
        df.drop(labels=(index), axis =0, inplace=True)
df = df.reset_index(drop=True)


# 3) Races where there were < or > 4 skaters: 
# a "race label" is assigned to each skater to determine which race they participated in and races whose labels are 
# counted more or less than 4 times are removed from the dataset
for index, row in df.iterrows():
    if (row['rank_lap5']==0.0 or row['rank_lap1']==5.0 or row['rank_lap2']==5.0 or row['rank_lap3']==5.0 or row['rank_lap4']==5.0 or row['rank_lap5']==5.0):
        df.drop(labels=(index), axis =0, inplace=True)
df = df.reset_index(drop=True)

arr = [None]*df['City'].count()
label = 0
for index, row in df.iterrows():
    if (row['Rank_In_Group'] == 1):
        label=label+1
        arr[index] = label
    else:
        arr[index] = label
        
df['Race_label'] = arr

value_counts = df['Race_label'].value_counts()
to_remove = value_counts[value_counts != 4].index
df = df[~df.Race_label.isin(to_remove)]
df = df.reset_index(drop=True)

df
# After this process, we are left with 2552 data points (638 races)
# Out:
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 2547  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2548  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2549  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2550  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2551  2015/2016               World Cup  Dordrecht     NED  2016      2   12
#
#      Distance          Round  Group  ...  rank_lap2 time_lap2 rank_lap3  \
# 0        500m  Preliminaries      1  ...        1.0      9.22       1.0
# 1        500m  Preliminaries      1  ...        2.0      9.31       2.0
# 2        500m  Preliminaries      1  ...        3.0      9.74       3.0
# 3        500m  Preliminaries      1  ...        4.0      9.93       4.0
# 4        500m  Preliminaries      2  ...        2.0      9.18       2.0
# ...       ...            ...    ...  ...        ...       ...       ...
# 2547     500m  RepSemifinals      2  ...        4.0      9.11       4.0
# 2548     500m  Quarterfinals      4  ...        1.0      8.91       1.0
# 2549     500m  Quarterfinals      4  ...        3.0      8.88       2.0
# 2550     500m  Quarterfinals      4  ...        2.0      8.95       3.0
# 2551     500m  Quarterfinals      4  ...        4.0      8.93       4.0
#
#       time_lap3  rank_lap4  time_lap4 rank_lap5  time_lap5   Time_Event  \
# 0          8.76        1.0       8.87       1.0       9.09  2013.046575
# 1          8.89        2.0       8.88       2.0       9.27  2013.046575
# 2          9.04        3.0       9.05       3.0       9.21  2013.046575
# 3          9.50        4.0       9.67       4.0       9.91  2013.046575
# 4          8.76        2.0       8.86       1.0       8.90  2013.046575
# ...         ...        ...        ...       ...        ...          ...
# 2547       8.35        4.0       8.65       4.0       9.29  2016.113470
# 2548       8.43        1.0       8.55       1.0       8.83  2016.113470
# 2549       8.33        2.0       8.57       2.0       8.81  2016.113470
# 2550       8.43        3.0       8.59       3.0       8.85  2016.113470
# 2551       8.45        4.0       8.48       4.0       8.84  2016.113470
#
#       Race_label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              2
# ...          ...
# 2547         980
# 2548         984
# 2549         984
# 2550         984
# 2551         984
#
# [2552 rows x 29 columns]

# %%
# PREPARING THE VARIABLES FOR THE LOGISTIC REGRESSION:
# The predictor variable will be the combination of intermediate rankings (categorical variable)
# The response variable will be the skater's rank in the 5th(last) lap (also represents his final rank for the race)

    
# CATEGORICAL PREDICTOR VARIABLE
# Combinations of intermediate rankings (value format: <rank in lap 1><rank in lap 2><rank in lap 3><rank in lap 4>)
interRanksLabel = [None]*df['City'].count()
for index, row in df.iterrows():  
    interRanksLabel[index] = str(int(df.iloc[index]["rank_lap1"])) + str(int(df.iloc[index]["rank_lap2"])) + str(int(df.iloc[index]["rank_lap3"])) + str(int(df.iloc[index]["rank_lap4"]))
df['interRanksLabel'] = interRanksLabel

# We end up with 89 different values for the categorical variable. To avoid overfitting the model, we remove values
# with occurences < 10
value_counts = df['interRanksLabel'].value_counts()
to_remove = value_counts[value_counts < 10].index
df = df[~df.interRanksLabel.isin(to_remove)]
df = df.reset_index(drop=True)

# Encoding the categorical values:
# We will use label encoding to encode the categorical values for logistic regression
df["interRanksLabel"] = df["interRanksLabel"].astype('category')
df["Categorical_label_code"] = df["interRanksLabel"].cat.codes


# RESPONSE VARIABLE
# The rankings for the last lap:
    # 0 if the skater did not finish the race in 1st place 
    # 1 if the skater finished the race in 1st place 
interRespLabel = [None]*df['City'].count()
for index, row in df.iterrows(): 
    if (row["rank_lap5"] != 1):
        interRespLabel[index] = 0
    else:
        interRespLabel[index] = 1
df["Response_Level"] = interRespLabel
df
# Out:
#          Season                  Series       City Country  Year  Month  Day  \
# 0     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 1     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 2     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 3     2012/2013  European Championships      Malmo     SWE  2013      1   18
# 4     2012/2013  European Championships      Malmo     SWE  2013      1   18
# ...         ...                     ...        ...     ...   ...    ...  ...
# 2358  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2359  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2360  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2361  2015/2016               World Cup  Dordrecht     NED  2016      2   12
# 2362  2015/2016               World Cup  Dordrecht     NED  2016      2   12
#
#      Distance          Round  Group  ...  time_lap3 rank_lap4 time_lap4  \
# 0        500m  Preliminaries      1  ...       8.89       2.0      8.88
# 1        500m  Preliminaries      1  ...       9.04       3.0      9.05
# 2        500m  Preliminaries      2  ...       8.76       2.0      8.86
# 3        500m  Preliminaries      2  ...       8.77       1.0      8.86
# 4        500m  Preliminaries      2  ...       8.94       3.0      9.05
# ...       ...            ...    ...  ...        ...       ...       ...
# 2358     500m  RepSemifinals      2  ...       8.35       4.0      8.65
# 2359     500m  Quarterfinals      4  ...       8.43       1.0      8.55
# 2360     500m  Quarterfinals      4  ...       8.33       2.0      8.57
# 2361     500m  Quarterfinals      4  ...       8.43       3.0      8.59
# 2362     500m  Quarterfinals      4  ...       8.45       4.0      8.48
#
#       rank_lap5  time_lap5   Time_Event Race_label  interRanksLabel  \
# 0           2.0       9.27  2013.046575          1             1222
# 1           3.0       9.21  2013.046575          1             4333
# 2           1.0       8.90  2013.046575          2             2222
# 3           2.0       9.01  2013.046575          2             1111
# 4           3.0       9.12  2013.046575          2             4333
# ...         ...        ...          ...        ...              ...
# 2358        4.0       9.29  2016.113470        980             4444
# 2359        1.0       8.83  2016.113470        984             1111
# 2360        2.0       8.81  2016.113470        984             3322
# 2361        3.0       8.85  2016.113470        984             2233
# 2362        4.0       8.84  2016.113470        984             4444
#
#       Categorical_label_code  Response_Level
# 0                          4               0
# 1                         23               0
# 2                          8               1
# 3                          0               0
# 4                         23               0
# ...                      ...             ...
# 2358                      27               0
# 2359                       0               1
# 2360                      16               0
# 2361                      11               0
# 2362                      27               0
#
# [2363 rows x 32 columns]

# %%
# APPLYING THE LOGISTIC REGRESSION MODEL

import statsmodels.api as sm
X=df['Categorical_label_code']
y=df['Response_Level']
logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367947
#          Iterations 7
#                             Results: Logit
# =======================================================================
# Model:                 Logit              Pseudo R-squared:   0.352
# Dependent Variable:    Response_Level     AIC:                1740.9165
# Date:                  2021-11-26 14:09   BIC:                1746.6842
# No. Observations:      2363               Log-Likelihood:     -869.46
# Df Model:              0                  LL-Null:            -1341.0
# Df Residuals:          2362               LLR p-value:        nan
# Converged:             1.0000             Scale:              1.0000
# No. Iterations:        7.0000
# -----------------------------------------------------------------------
#                         Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------
# Categorical_label_code -0.1642   0.0070 -23.6016 0.0000 -0.1779 -0.1506
# =======================================================================

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# X_train = X_train.array
# X_test = X_test.array
# y_train = y_train.array

# y_test.values

# %%
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train.values.reshape(-1, 1),y_train.values.reshape(-1, 1))

#
y_pred=logreg.predict(X_test.values.reshape(-1, 1))
# Out:
# /opt/anaconda3/envs/sports/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
# %matplotlib inline
pd.crosstab(X,y).plot(kind='bar')
plt.show()

# %%
df2 = df["interRanksLabel"].value_counts().rename_axis('unique_values').reset_index(name='counts')
df2
# Out:
#    unique_values  counts
# 0           1111     445
# 1           4444     430
# 2           3333     314
# 3           2222     308
# 4           3332      61
# 5           1112      59
# 6           4443      55
# 7           3444      55
# 8           2223      50
# 9           2111      50
# 10          3322      50
# 11          2211      49
# 12          2221      48
# 13          4333      46
# 14          4433      44
# 15          1122      42
# 16          2233      37
# 17          1222      34
# 18          3344      34
# 19          3334      29
# 20          3222      26
# 21          2333      20
# 22          2224      15
# 23          4332      15
# 24          3321      13
# 25          1113      13
# 26          2234      11
# 27          4442      10

# %%
df["interRanksLabel"].value_counts()
# Out:
# 1111    445
# 4444    430
# 3333    314
# 2222    308
# 3332     61
# 1112     59
# 4443     55
# 3444     55
# 2223     50
# 2111     50
# 3322     50
# 2211     49
# 2221     48
# 4333     46
# 4433     44
# 1122     42
# 2233     37
# 1222     34
# 3344     34
# 3334     29
# 3222     26
# 2333     20
# 2224     15
# 4332     15
# 3321     13
# 1113     13
# 2234     11
# 4442     10
# Name: interRanksLabel, dtype: int64
